# %%
import requests
from wordcloud import WordCloud
import matplotlib.pyplot as plt

#define the API endpoint
API_URL = 'https://corporatebs-generator.sameerkumar.website/'

#function to generate corporate jargon
def generate_corporate_bs(num_phrases):
    phrases = []
    for _ in range(num_phrases):
        response = requests.get(API_URL)
        if response.status_code == 200:
            phrases.append(response.json()['phrase'])
        else:
            print("Error retrieving data:", response.status_code)
    return phrases

#generate and display a list of corporate jargon phrases
num_phrases = 50  # Number of phrases to generate
jargon_phrases = generate_corporate_bs(num_phrases)

print("Corporate Jargon Phrases:")
for i, phrase in enumerate(jargon_phrases):
    print(f"{i + 1}: {phrase}")

#combine phrases into a single text for the word cloud
combined_phrases = ' '.join(jargon_phrases)

#filter out single-character words and any unwanted characters
filtered_phrases = ' '.join(word for word in combined_phrases.split() if len(word) > 1 and word.isalpha())

#generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(filtered_phrases)

#display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Corporate Jargon Word Cloud")
plt.show()
# Out:
# Corporate Jargon Phrases:
# 1: Authoritatively Streamline Worldwide Catalysts For Change
# 2: Monotonectally Expedite Go Forward Technologies
# 3: Holisticly Build Plug-and-play Strategic Theme Areas
# 4: Distinctively Matrix Stand-alone Leadership
# 5: Competently Exploit Stand-alone Resources
# 6: Synergistically Streamline Customized Best Practices
# 7: Phosfluorescently Exploit Granular Communities
# 8: Energistically Administrate Cloud-centric Best Practices
# 9: Efficiently Monetize Customer Directed Strategic Theme Areas
# 10: Distinctively Provide Access To Pandemic Metrics
# 11: Competently Disseminate Visionary "Outside The Box" Thinking
# 12: Enthusiastically Develop Ethical Schemas
# 13: Competently Restore Value-added Bandwidth
# 14: Monotonectally E-enable Tactical Alignments
# 15: Energistically Right-shore Low-risk High-yield Markets
# 16: Collaboratively Coordinate Compelling Methodologies
# 17: Enthusiastically Leverage Existing Maintainable Paradigms
# 18: Distinctively Benchmark Multidisciplinary Ideas
# 19: Compellingly Productize B2b Strategic Theme Areas
# 20: Authoritatively Administrate 24/7 Quality Vectors
# 21: Quickly Parallel Task Ubiquitous Storage
# 22: Enthusiastically Seize Stand-alone Functionalities
# 23: Assertively Unleash Reliable Vortals
# 24: Appropriately Fashion Impactful Human Capital
# 25: Intrinsically Recaptiualize Magnetic Methodologies
# 26: Enthusiastically Enhance Best-of-breed Applications
# 27: Uniquely Revolutionize State Of The Art Ideas
# 28: Uniquely Monetize Performance Based Outsourcing
# 29: Professionally Engineer Proactive Data
# 30: Appropriately Cloudify High-quality Expertise
# 31: Phosfluorescently Right-shore Sticky Products
# 32: Holisticly Create Fully Researched Materials
# 33: Objectively Supply Front-end Data
# 34: Interactively Visualize Collaborative Supply Chains
# 35: Dynamically Enable Competitive Fungibility
# 36: Globally Foster Progressive Technologies
# 37: Competently Deploy Flexible Meta-services
# 38: Rapidiously Incubate Tactical Content
# 39: Continually Network Multifunctional Process Improvements
# 40: Fungibly Fashion Cloud-based Process Improvements
# 41: Completely Develop Elastic E-tailers
# 42: Appropriately Supply Equity Invested Meta-services
# 43: Globally Optimize Clicks-and-mortar E-business
# 44: Competently Myocardinate Bleeding-edge Quality Vectors
# 45: Uniquely Reconceptualize Future-proof E-markets
# 46: Assertively Visualize Cross-unit Benefits
# 47: Uniquely Network Functionalized Metrics
# 48: Dynamically Fabricate Multidisciplinary Systems
# 49: Phosfluorescently Cultivate Worldwide Architectures
# 50: Uniquely Re-engineer Process-centric Innovation
